# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 3.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 2.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 2.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 1.6 MB/s eta 0:00:00
# ...
#   Using cached Pillow-9.3.0-cp310-cp310-macosx_10_10_x86_64.whl (3.3 MB)
# ...

# %%
import pandas as pd

co2 = pd.read_csv('Datasets/Co2.csv')

print(co2.to_string())
# Out:
#      SensorID        Date      Time  CO2 Instantaneous ppm CO2 TWA ppm
# 0      687589  11/19/2022   7:54 am                      0           0
# 1      687589  11/19/2022   7:39 am                      0           0
# 2      687589  11/19/2022   7:24 am                      0           0
# 3      687589  11/19/2022   7:09 am                      0           0
# 4      687589  11/19/2022   6:54 am                      0           0
# 5      687589  11/19/2022   6:39 am                      0           0
# 6      687589  11/19/2022   6:24 am                      0           0
# 7      687589  11/19/2022   6:09 am                      0           0
# 8      687589  11/19/2022   5:54 am                      0           0
# 9      687589  11/19/2022   5:39 am                      0           0
# 10     687589  11/19/2022   5:24 am                      0           1
# 11     687589  11/19/2022   5:09 am                      0           1
# ...

# %%
light = pd.read_csv('Datasets/light.csv')
co2 = pd.read_csv('Datasets/Co2.csv')
Door1 = pd.read_csv('Datasets/door1.csv')
Door2 = pd.read_csv('Datasets/door2.csv')
Door3 = pd.read_csv('Datasets/door3.csv')
Humidity1 = pd.read_csv('Datasets/humid_temp_1.csv')
Humidity2 = pd.read_csv('Datasets/humid_temp_2.csv')
Vibration = pd.read_csv('Datasets/vibration.csv')
Motion = pd.read_csv('Datasets/motion.csv')



def To24(df):
    return pd.to_datetime(df, format='%I:%M %p').dt.strftime('%H:%M:%S');

def ToDateTime(Date, Time):
    return pd.to_datetime(Date + ' ' + Time)


def NormalizeData(df, Columns):
    df[Columns] = (df[Columns]-df[Columns].mean())/df[Columns].std()
        
#Change time to 24 hours

def TimePlot(df, dataColumns, to24=True):
    #To 24 hours (Not for humidity)
    if(to24):
        df['Time']=To24(df['Time'])
    df['DateTime'] = ToDateTime(df['Date'], df['Time'])
    #NormalizeData(df, dataColumns)

TimePlot(light, ['Value']) 
TimePlot(co2, ['Inst', 'TWA'])    
TimePlot(Door1, ['Value'])  
TimePlot(Door2, ['Value']) 
TimePlot(Door3, ['Value'])  
TimePlot(Humidity1, ['Humidity', 'Temperature'], False)  
TimePlot(Humidity2, ['Humidity', 'Temperature'], False)  
#TimePlot(Vibration, ['Inst', 'TWA'])  
TimePlot(Motion, ['Value'])  


Humidity1 = Humidity1[Humidity1['DateTime'] > "2022-11-14 10:08:00"]
Humidity2 = Humidity2[Humidity2['DateTime'] > "2022-11-14 10:58:00"]
'''
light['Time']=To24(light['Time'])
light['DateTime'] = ToDateTime(light['Date'], light['Time'])
NormalizeData(light, ['Value'])

co2['Time']=To24(co2['Time'])
co2['DateTime'] = ToDateTime(co2['Date'], co2['Time'])
NormalizeData(co2, ['Inst','TWA'])
'''


#NormalizeData(co2, ['TWA'])
#DateTime = pd.to_datetime(light['Date'] + ' ' + light['Time'])
#print(co2.to_string()) 
from matplotlib import pyplot as plt
#plt.plot(light['DateTime'], light['Value'],label = "light")
#plt.plot(co2['DateTime'], co2['Inst'],label = "co2")
#plt.plot(co2['DateTime'], co2['TWA'],label = "Twa")
#plt.plot(Door1['DateTime'], Door1['Value'],label = "Door1")
#plt.plot(Door2['DateTime'], Door2['Value'],label = "Door2")
#plt.plot(Door3['DateTime'], Door3['Value'],label = "Door3")
#plt.plot(Humidity1['DateTime'], Humidity1['Humidity'],label = "Humidity1")
#plt.plot(Humidity2['DateTime'], Humidity2['Humidity'],label = "Humidity2")
plt.plot(Humidity1['DateTime'], Humidity1['Temperature'],label = "Temperature1")
plt.plot(Humidity2['DateTime'], Humidity2['Temperature'],label = "Tempearture2")
#plt.plot(Motion['DateTime'], Motion['Value'],label = "Motion")
plt.legend()
plt.show()

# %%
Humidity1.to_csv('Humidity1-filtered.csv', index=False)
